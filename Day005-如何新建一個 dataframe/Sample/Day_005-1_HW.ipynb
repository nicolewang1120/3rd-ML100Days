# %% [markdown]
# # [作業目標]
# - 利用範例的創建方式, 創建一組資料, 並練習如何取出最大值

# %% [markdown]
# # [作業重點]
# - 練習創立 DataFrame (In[2])
# - 如何取出口數最多的國家 (In[3], Out[3])

# %% [markdown]
# ## 練習時間
# 在小量的資料上，我們用眼睛就可以看得出來程式碼是否有跑出我們理想中的結果
#
# 請嘗試想像一個你需要的資料結構 (裡面的值可以是隨機的)，然後用上述的方法把它變成 pandas DataFrame
#
# #### Ex: 想像一個 dataframe 有兩個欄位，一個是國家，一個是人口，求人口數最多的國家
#
# ### Hints: [隨機產生數值](https://blog.csdn.net/christianashannon/article/details/78867204)

# %%
import pandas as pd
import numpy as np

# %%
# -*- coding: utf-8 -*-
"""Untitled1.ipynb

Automatically generated by Colaboratory.

Original file is located at
    https://colab.research.google.com/drive/18NP4dioEWl6D4n3qOnjgFHLMw_mglfyI
"""
import os 

dir_data = 'c:/data/'
f_app_cntry = os.path.join(dir_data, 'country.csv')
df = pd.read_csv(f_app_cntry)

print(df)

type(df)

cntry_list= np.random.choice(df.id,5)
print(cntry_list)

for c in cntry_list:
  print(c)

dic_cntry = {}

import random
for c in cntry_list:
  persons =  random.randint(1,10000)
  print(persons)
  dic_cntry[c] = persons

print(dic_cntry )

select = pd.Series(dic_cntry,index = dic_cntry.keys())
print(select)
# Out:
#      id      value
# 0    TT    千里達及托巴哥
# 1    TR        土耳其
# 2    TC  土克斯及開科斯群島
# 3    TM        土庫曼
# 4    BT         不丹
# 5    CF      中非共和國
# 6    CN         中國
# 7    HK  中國香港特別行政區
# 8    MO  中國澳門特別行政區
# 9    DK         丹麥
# 10   EC        厄瓜多
# 11   ER       厄利垂亞
# 12   PG    巴布亞紐幾內亞
# 13   BR         巴西
# 14   BB        巴貝多
# 15   PY        巴拉圭
# 16   BH         巴林
# 17   BS        巴哈馬
# 18   PA        巴拿馬
# 19   PS    巴勒斯坦自治區
# 20   PK       巴基斯坦
# 21   JP         日本
# 22   BE        比利時
# 23   JM        牙買加
# 24   IL        以色列
# 25   IC      加那利群島
# 26   CA        加拿大
# 27   GA         加彭
# 28   MP    北馬利安納群島
# 29   MK       北馬其頓
# ..   ..        ...
# 225  CV        維德角
# 226  MN         蒙古
# 227  MS        蒙哲臘
# 228  ME      蒙特內哥羅
# 229  BI        蒲隆地
# 230  GY        蓋亞那
# 231  LA         寮國
# 232  DE         德國
# 233  MA        摩洛哥
# 234  MC        摩納哥
# 235  MD       摩爾多瓦
# 236  MU       模里西斯
# 237  MM         緬甸
# 238  LB        黎巴嫩
# 239  MX        墨西哥
# ...
